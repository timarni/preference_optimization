# %% [markdown]
# ### Notebook to use the OpenAI API to send requests in batch mode
#
# * Cell 1: Import functions from the _interact_with_gpt_batch_version.py_ script
# * Cell 2: Load prompts and check if size is correct
# * Cell 3: Launch batch job, requires path file to batch and description of the job as attributes (WARNING: WILL COST MONEY)
# * Cell 4: Check status of job
# * Cell 5: Once the job is completed, the results can be retrieved
# * Cell 6: Get an overview of the last 20 jobs (useful if results need to be retrieved again)

# %%
# Import scripts with the functions to interact with the OpenAI API
import interact_with_gpt_batch_version as script

# %%
# Load file of batched prompts and check if it is the correct file:

# Define the file path
file_path = "../results/batched_prompts_test.jsonl"
batch_description = "Generate prompts that health care workers might ask to a medical AI chatbot, later used for DPO"

# Initialize a counter
count = 0

# Open the file and count each line
with open(file_path, 'r') as file:
    for line in file:
        count += 1

print("Number of entries:", count)
# Out:
# Number of entries: 637

# %%
# Launch batch job
# Decomment line below to run job using openai API in batch mode
# WILL COST MONEY
# script.process_batch_by_gpt(path_to_batched_prompts = file_path, description=batch_description)
# Out:
# Connecting to openai
# Creating batch file
# Batch file successfully created
# FileObject(id='file-J5ZkdDHSrPibmNFPbiJwaZ', bytes=1680922, created_at=1732987236, filename='batched_prompts_test.jsonl', object='file', purpose='batch', status='processed', status_details=None)
# Launch batch
# Batch successfully launched
# Batch id saved to ../results/batch_id.txt and batch object saved to ../results/batch.txt

# %%
# get status of batched job
script.get_batch_status()
# Out:
# Batch(id='batch_674b4966370081908db854c94592dc2a', completion_window='24h', created_at=1732987238, endpoint='/v1/chat/completions', input_file_id='file-J5ZkdDHSrPibmNFPbiJwaZ', object='batch', status='in_progress', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1733073638, failed_at=None, finalizing_at=None, in_progress_at=1732987238, metadata={'description': 'Generate prompts that health care workers might ask to a medical AI chatbot, later used for DPO'}, output_file_id=None, request_counts=BatchRequestCounts(completed=83, failed=0, total=637))
# status = in_progress

# %%
# retrieve results
script.retrieve_results()

# %%
# Get list of jobs
from openai import OpenAI

path_to_api_key: str = "../API_KEY.txt"

my_api_key = open(path_to_api_key, 'r').read()
client = OpenAI(api_key=my_api_key)


client.batches.list()
# Out:
# SyncCursorPage[Batch](data=[Batch(id='batch_674b4966370081908db854c94592dc2a', completion_window='24h', created_at=1732987238, endpoint='/v1/chat/completions', input_file_id='file-J5ZkdDHSrPibmNFPbiJwaZ', object='batch', status='in_progress', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1733073638, failed_at=None, finalizing_at=None, in_progress_at=1732987238, metadata={'description': 'Generate prompts that health care workers might ask to a medical AI chatbot, later used for DPO'}, output_file_id=None, request_counts=BatchRequestCounts(completed=16, failed=0, total=637)), Batch(id='batch_674b043ad74c8190b83607b3f4fbc9c6', completion_window='24h', created_at=1732969530, endpoint='/v1/chat/completions', input_file_id='file-KZz48uCzgMAhGkVojnYiVd', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1732970747, error_file_id=None, errors=None, expired_at=None, expires_at=1733055930, failed_at=None, finalizing_at=1732970641, in_progress_at=1732969533, metadata={'description': 'ct2 enhancing - part_2.jsonl'}, output_file_id='file-LDsYgDWP7xdvFYmH8aKjUU', request_counts=BatchRequestCounts(completed=1667, failed=0, total=1667)), Batch(id='batch_674b042dcc788190ada4f166ce668383', completion_window='24h', created_at=1732969517, endpoint='/v1/chat/completions', input_file_id='file-8UbnSnG6zwGkvgiqMpRG6p', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1732970706, error_file_id=None, errors=None, expired_at=None, expires_at=1733055917, failed_at=None, finalizing_at=1732970455, in_progress_at=1732969525, metadata={'description': 'ct2 enhancing - part_1.jsonl'}, output_file_id='file-KuSGw2fqHWouiP1RZk4JH3', request_counts=BatchRequestCounts(completed=2435, failed=0, total=2435)), Batch(id='batch_674a077ac4e48190b90627918f456114', completion_window='24h', created_at=1732904826, endpoint='/v1/chat/completions', input_file_id='file-TRnebs5HuDukgDUYUHJHwV', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1732906707, error_file_id=None, errors=None, expired_at=None, expires_at=1732991226, failed_at=None, finalizing_at=1732906188, in_progress_at=1732904829, metadata=None, output_file_id='file-YRYY89hrUk8FQMKk5RyL3m', request_counts=BatchRequestCounts(completed=4928, failed=0, total=4928)), Batch(id='batch_674a07521b508190a2dce12f3f33db42', completion_window='24h', created_at=1732904786, endpoint='/v1/chat/completions', input_file_id='file-B4DC35TigNXrkwT78RceBm', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1732906773, error_file_id=None, errors=None, expired_at=None, expires_at=1732991186, failed_at=None, finalizing_at=1732906269, in_progress_at=1732904788, metadata=None, output_file_id='file-PCBNpsJgLer1CHWjGkieoG', request_counts=BatchRequestCounts(completed=4928, failed=0, total=4928)), Batch(id='batch_6749e32b2db881909c5f6499364dca22', completion_window='24h', created_at=1732895531, endpoint='/v1/chat/completions', input_file_id='file-V4qAJJUKeUAMYF2svKLHmp', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1732897579, error_file_id=None, errors=None, expired_at=None, expires_at=1732981931, failed_at=None, finalizing_at=1732896972, in_progress_at=1732895533, metadata=None, output_file_id='file-35q3kozu9uuKF2sXPtgVPd', request_counts=BatchRequestCounts(completed=4928, failed=0, total=4928)), Batch(id='batch_6749e31d731c8190b821d114d37167a1', completion_window='24h', created_at=1732895517, endpoint='/v1/chat/completions', input_file_id='file-JGKL5rWibQktMQGvT8ZE2W', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1732897160, error_file_id=None, errors=None, expired_at=None, expires_at=1732981917, failed_at=None, finalizing_at=1732896857, in_progress_at=1732895518, metadata=None, output_file_id='file-EPyjm2D6FeyGVzUg6LjcUF', request_co ...
